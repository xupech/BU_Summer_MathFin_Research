# %%
from ML2020 import *
import warnings
warnings.filterwarnings("ignore")

# %%
param_dict = {'num_stocks':40,
              'trading_window' : 12,
              'time_list' : ['2015-10-01', '2019-07-01'],
              'strategy' : 'long_equal_weighted',
              'algorithm': "LSTM",
              'fill_in_method': 'median',
              'pca': True
}

# %%
def one_step_function(raw_data, param_dict):
    
    ML_object = MLEngineer(raw_data, num_stocks = param_dict['num_stocks'],
                       trading_window = param_dict['trading_window'], algorithm = param_dict['algorithm'], small_sample = False, method = param_dict['fill_in_method'], pca = param_dict['pca'])
    ML_object.data_processing()
    
    returns = ML_object.profit_construct(param_dict['time_list'], strategy = param_dict['strategy'])
    
    ML_object.return_plot(returns)
    
    return ML_object

# %% [markdown]
# ###  1. Data Cleaning

# %%
raw_data = pd.read_csv("fun_tech_2013_median.csv")

# %%
ML_object = one_step_function(raw_data, param_dict)
# Out:
# date format corrected
# missing indicator variables deleted
# continous variables containing infinity deleted
# missing continuous variables filled in with median
# 2015-10
# Epoch 1/100
# 3/3 [==============================] - 0s 2ms/step - loss: 2.1595
# Epoch 2/100
# 3/3 [==============================] - 0s 2ms/step - loss: 2.1528
# Epoch 3/100
# 3/3 [==============================] - 0s 2ms/step - loss: 2.1469
# Epoch 4/100
# 3/3 [==============================] - 0s 2ms/step - loss: 2.1364
# Epoch 5/100
# 3/3 [==============================] - 0s 2ms/step - loss: 2.1249
# Epoch 6/100
# 3/3 [==============================] - 0s 3ms/step - loss: 2.1042
# Epoch 7/100
# 3/3 [==============================] - 0s 3ms/step - loss: 2.1191
# Epoch 8/100
# 3/3 [==============================] - 0s 2ms/step - loss: 2.0891
# Epoch 9/100
# 3/3 [==============================] - 0s 3ms/step - loss: 2.0845
# Epoch 10/100
# 3/3 [==============================] - 0s 3ms/step - loss: 2.1077
# Epoch 11/100
# 3/3 [==============================] - 0s 3ms/step - loss: 2.0767
# Epoch 12/100
# 3/3 [==============================] - 0s 2ms/step - loss: 2.0845
# Epoch 13/100
# 3/3 [==============================] - 0s 3ms/step - loss: 2.0884
# Epoch 14/100
# 3/3 [==============================] - 0s 2ms/step - loss: 2.0677
# Epoch 15/100
# 3/3 [==============================] - 0s 2ms/step - loss: 2.0508
# Epoch 16/100
# 3/3 [==============================] - 0s 3ms/step - loss: 2.0609
# Epoch 17/100
# 3/3 [==============================] - 0s 3ms/step - loss: 2.0302
# Epoch 18/100
# 3/3 [==============================] - 0s 3ms/step - loss: 2.0191
# Epoch 19/100
# 3/3 [==============================] - 0s 3ms/step - loss: 1.9970
# Epoch 20/100
# 3/3 [==============================] - 0s 2ms/step - loss: 2.0089
# Epoch 21/100
# 3/3 [==============================] - 0s 2ms/step - loss: 1.9290
# Epoch 22/100
# 3/3 [==============================] - 0s 3ms/step - loss: 1.9293
# Epoch 23/100
# 3/3 [==============================] - 0s 3ms/step - loss: 1.9587
# Epoch 24/100
# 3/3 [==============================] - 0s 2ms/step - loss: 2.0033
# Epoch 25/100
# 3/3 [==============================] - 0s 2ms/step - loss: 1.9131
# Epoch 26/100
# 3/3 [==============================] - 0s 2ms/step - loss: 1.9411
# Epoch 27/100
# 3/3 [==============================] - 0s 3ms/step - loss: 1.8941
# Epoch 28/100
# 3/3 [==============================] - 0s 4ms/step - loss: 1.8597
# Epoch 29/100
# 3/3 [==============================] - 0s 3ms/step - loss: 1.9365
# Epoch 30/100
# 3/3 [==============================] - 0s 2ms/step - loss: 1.8955
# Epoch 31/100
# 3/3 [==============================] - 0s 3ms/step - loss: 1.8622
# Epoch 32/100
# 3/3 [==============================] - 0s 2ms/step - loss: 1.8618
# Epoch 33/100
# 3/3 [==============================] - 0s 5ms/step - loss: 1.8545
# Epoch 34/100
# 3/3 [==============================] - 0s 5ms/step - loss: 1.7826
# Epoch 35/100
# 3/3 [==============================] - 0s 4ms/step - loss: 1.7841
# Epoch 36/100
# 3/3 [==============================] - 0s 2ms/step - loss: 1.8242
# Epoch 37/100
# 3/3 [==============================] - 0s 4ms/step - loss: 1.8900
# Epoch 38/100
# 3/3 [==============================] - 0s 4ms/step - loss: 1.7862
# Epoch 39/100
# 3/3 [==============================] - 0s 3ms/step - loss: 1.7972
# Epoch 40/100
# 3/3 [==============================] - 0s 3ms/step - loss: 1.7960
# Epoch 41/100
# 3/3 [==============================] - 0s 3ms/step - loss: 1.7532
# Epoch 42/100
# 3/3 [==============================] - 0s 2ms/step - loss: 1.7247
# Epoch 43/100
# 3/3 [==============================] - 0s 3ms/step - loss: 1.8107
# Epoch 44/100
# 3/3 [==============================] - 0s 2ms/step - loss: 1.7827
# Epoch 45/100
# 3/3 [==============================] - 0s 3ms/step - loss: 1.6699
# Epoch 46/100
# 3/3 [==============================] - 0s 4ms/step - loss: 1.6603
# Epoch 47/100
# 3/3 [==============================] - 0s 3ms/step - loss: 1.6271
# Epoch 48/100
# 3/3 [==============================] - 0s 2ms/step - loss: 1.7236
# Epoch 49/100
# 3/3 [==============================] - 0s 4ms/step - loss: 1.6132
# Epoch 50/100
# 3/3 [==============================] - 0s 3ms/step - loss: 1.6686
# Epoch 51/100
# 3/3 [==============================] - 0s 3ms/step - loss: 1.6870
# Epoch 52/100
# 3/3 [==============================] - 0s 3ms/step - loss: 1.6589
# Epoch 53/100
# 3/3 [==============================] - 0s 2ms/step - loss: 1.7094
# Epoch 54/100
# 3/3 [==============================] - 0s 3ms/step - loss: 1.6128
# Epoch 55/100
# 3/3 [==============================] - 0s 2ms/step - loss: 1.6158
# Epoch 56/100
# 3/3 [==============================] - 0s 3ms/step - loss: 1.6024
# Epoch 57/100
# 3/3 [==============================] - 0s 3ms/step - loss: 1.6563
# Epoch 58/100
# 3/3 [==============================] - 0s 2ms/step - loss: 1.6067
# Epoch 59/100
# 3/3 [==============================] - 0s 3ms/step - loss: 1.5942
# Epoch 60/100
# 3/3 [==============================] - 0s 3ms/step - loss: 1.6626
# Epoch 61/100
# 3/3 [==============================] - 0s 3ms/step - loss: 1.7573
# Epoch 62/100
# 3/3 [==============================] - 0s 3ms/step - loss: 1.7393
# Epoch 63/100
# 3/3 [==============================] - 0s 3ms/step - loss: 1.5556
# Epoch 64/100
# 3/3 [==============================] - 0s 3ms/step - loss: 1.5925
# Epoch 65/100
# 3/3 [==============================] - 0s 4ms/step - loss: 1.4967
# Epoch 66/100
# 3/3 [==============================] - 0s 3ms/step - loss: 1.5042
# Epoch 67/100
# 3/3 [==============================] - 0s 3ms/step - loss: 1.6476
# Epoch 68/100
# 3/3 [==============================] - 0s 3ms/step - loss: 1.5161
# Epoch 69/100
# 3/3 [==============================] - 0s 3ms/step - loss: 1.6155
# Epoch 70/100
# 3/3 [==============================] - 0s 3ms/step - loss: 1.5136
# Epoch 71/100
# 3/3 [==============================] - 0s 3ms/step - loss: 1.5001
# Epoch 72/100
# 3/3 [==============================] - 0s 2ms/step - loss: 1.5153
# Epoch 73/100
# 3/3 [==============================] - 0s 3ms/step - loss: 1.5434
# Epoch 74/100
# 3/3 [==============================] - 0s 3ms/step - loss: 1.
100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.4098
# Epoch 4/100
# 1/1 [==============================] - 0s 574us/step - loss: 1.4755
# Epoch 5/100
# 1/1 [==============================] - 0s 751us/step - loss: 1.3935
# Epoch 6/100
# 1/1 [==============================] - 0s 951us/step - loss: 1.3320
# Epoch 7/100
# 1/1 [==============================] - 0s 639us/step - loss: 1.3950
# Epoch 8/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.3524
# Epoch 9/100
# 1/1 [==============================] - 0s 872us/step - loss: 1.2915
# Epoch 10/100
# 1/1 [==============================] - 0s 879us/step - loss: 1.3941
# Epoch 11/100
# 1/1 [==============================] - 0s 986us/step - loss: 1.2889
# Epoch 12/100
# 1/1 [==============================] - 0s 818us/step - loss: 1.3523
# Epoch 13/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.2792
# Epoch 14/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.2340
# Epoch 15/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.1496
# Epoch 16/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.3442
# Epoch 17/100
# 1/1 [==============================] - 0s 857us/step - loss: 1.2202
# Epoch 18/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.1147
# Epoch 19/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.2284
# Epoch 20/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.2980
# Epoch 21/100
# 1/1 [==============================] - 0s 794us/step - loss: 1.2172
# Epoch 22/100
# 1/1 [==============================] - 0s 868us/step - loss: 1.2149
# Epoch 23/100
# 1/1 [==============================] - 0s 642us/step - loss: 1.1589
# Epoch 24/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.3209
# Epoch 25/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.1856
# Epoch 26/100
# 1/1 [==============================] - 0s 684us/step - loss: 1.1696
# Epoch 27/100
# 1/1 [==============================] - 0s 719us/step - loss: 1.2620
# Epoch 28/100
# 1/1 [==============================] - 0s 713us/step - loss: 1.3067
# Epoch 29/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.1615
# Epoch 30/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.3054
# Epoch 31/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.2417
# Epoch 32/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.1510
# Epoch 33/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.2276
# Epoch 34/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.1906
# Epoch 35/100
# 1/1 [==============================] - 0s 886us/step - loss: 1.3588
# Epoch 36/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.3632
# Epoch 37/100
# 1/1 [==============================] - 0s 962us/step - loss: 1.1816
# Epoch 38/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.1454
# Epoch 39/100
# 1/1 [==============================] - 0s 959us/step - loss: 1.1392
# Epoch 40/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.1388
# Epoch 41/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.2923
# Epoch 42/100
# 1/1 [==============================] - 0s 799us/step - loss: 1.1830
# Epoch 43/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.8977
# Epoch 44/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.9944
# Epoch 45/100
# 1/1 [==============================] - 0s 4ms/step - loss: 1.0677
# Epoch 46/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.2198
# Epoch 47/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2408
# Epoch 48/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.3479
# Epoch 49/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.1163
# Epoch 50/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.1577
# Epoch 51/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.0819
# Epoch 52/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.0854
# Epoch 53/100
# 1/1 [==============================] - 0s 880us/step - loss: 1.1230
# Epoch 54/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.1187
# Epoch 55/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.1891
# Epoch 56/100
# 1/1 [==============================] - 0s 919us/step - loss: 1.1682
# Epoch 57/100
# 1/1 [==============================] - 0s 713us/step - loss: 1.0362
# Epoch 58/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.9522
# Epoch 59/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.0909
# Epoch 60/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.1667
# Epoch 61/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.3578
# Epoch 62/100
# 1/1 [==============================] - 0s 996us/step - loss: 1.1211
# Epoch 63/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7279
# Epoch 64/100
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1317
# Epoch 65/100
# 1/1 [==============================] - 0s 842us/step - loss: 1.1307
# Epoch 66/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.9626
# Epoch 67/100
# 1/1 [==============================] - 0s 895us/step - loss: 1.1979
# Epoch 68/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.7785
# Epoch 69/100
# 1/1 [==============================] - 0s 768us/step - loss: 0.9438
# Epoch 70/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.0769
# Epoch 71/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.1105
# Epoch 72/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.9665
# Epoch 73/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.9618
# Epoch 74/100
# 1/1 [==============================] - 0s 4ms/step - loss: 1.1836
# Epoch 75/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.0065
# Epoch 76/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.1220
# Epoch 77/100
# 1/1 [==============================] - 0s 818us/step - loss: 0.9639
# Epoch 78/100
# 1/1 [==============================] - 0s 4ms/step - loss: 1.0682
# Epoch 79/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.0140
# Epoch 80/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.0085
# Epoch 81/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.9680
# Epoch 82/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.9719
# Epoch 83/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.0498
# Epoch 84/100
# 1/1 [==============================] - 0s 879us/step - loss: 0.8974
# Epoch 85/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.9155
# Epoch 86/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.8744
# Epoch 87/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.8811
# Epoch 88/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.9598
# Epoch 89/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.9808
# Epoch 90/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.8123
# Epoch 91/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.9953
# Epoch 92/100
# 1/1 [==============================] - 0s 933us/step - loss: 1.1365
# Epoch 93/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.1114
# Epoch 94/100
# 1/1 [==============================] - 0s 969us/step - loss: 0.9124
# Epoch 95/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.7527
# Epoch 96/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7744
# Epoch 97/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7747
# Epoch 98/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7702
# Epoch 99/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.1757
# Epoch 100/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.7694
# Epoch 1/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6735
# Epoch 2/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6582
# Epoch 3/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6427
# Epoch 4/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6243
# Epoch 5/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5992
# Epoch 6/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5897
# Epoch 7/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5611
# Epoch 8/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5430
# Epoch 9/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5241
# Epoch 10/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5094
# Epoch 11/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5107
# Epoch 12/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5066
# Epoch 13/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4920
# Epoch 14/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4887
# Epoch 15/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4597
# Epoch 16/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4586
# Epoch 17/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4436
# Epoch 18/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4461
# Epoch 19/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4139
# Epoch 20/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4261
# Epoch 21/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4234
# Epoch 22/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4167
# Epoch 23/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4156
# Epoch 24/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4004
# Epoch 25/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4092
# Epoch 26/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3899
# Epoch 27/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3844
# Epoch 28/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3819
# Epoch 29/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3848
# Epoch 30/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3814
# Epoch 31/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3831
# Epoch 32/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3810
# Epoch 33/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3793
# Epoch 34/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3762
# Epoch 35/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3533
# Epoch 36/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3612
# Epoch 37/100
# 1/8 [==>...........................] - ETA: 0s - loss: 0.3403
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-c3de7d2f56ce> in <module>
# ----> 1 ML_object = one_step_function(raw_data, param_dict)
#
# <ipython-input-7-6aeb5541d2ad> in one_step_function(raw_data, param_dict)
#       5     ML_object.data_processing()
#       6
# ----> 7     returns = ML_object.profit_construct(param_dict['time_list'], strategy = param_dict['strategy'])
#       8
#       9     ML_object.return_plot(returns)
#
# ~/Desktop/Research/Machine Learning/ML in Math Finance MK/2020/Summer_ML/ML2020.py in profit_construct(self, time_list, strategy)
#     179         while time_step != time_end:
#     180             print(time_step)
# --> 181             port_id, indx_rank = self.opti_stocks(time_step)
#     182
#     183             if strategy == 'long_equal_weighted':
#
# ~/Desktop/Research/Machine Learning/ML in Math Finance MK/2020/Summer_ML/ML2020.py in opti_stocks(self, time_step)
#     150             Method to output optimally selected stocks
#     151         """
# --> 152         y_hat, y_test = self.return_prediction(time_step)
#     153         indx_rank = np.argsort(y_hat)
#     154 #        print(y_hat)
#
# ~/Desktop/Research/Machine Learning/ML in Math Finance MK/2020/Summer_ML/ML2020.py in return_prediction(self, time_step)
#      76             model = self.model(self.x_train.loc[flag_train],self.y_train.loc[flag_train], self.x_test[flag_test], self.y_test[flag_test])
#      77             #model.tunning()
# ---> 78             model.training()
#      79             y_hat[flag_test] = model.predict()
#      80
#
# ~/Desktop/Research/Machine Learning/ML in Math Finance MK/2020/Summer_ML/LSTM.py in training(self)
#      80         """
#      81
# ---> 82         self.model.fit(self.train_x, self.train_y, epochs=100, batch_size=300)
#      83
#      84     def tunning(self, nfolds=5):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     805       # In this case we have created variables on the first call, so we run the
#     806       # defunned version which is guaranteed to never create variables.
# --> 807       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     808     elif self._stateful_fn is not None:
#     809       # Release the lock early so that multiple threads can perform the call
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1846                            resource_variable_ops.BaseResourceVariable))],
#    1847         captured_inputs=self.captured_inputs,
# -> 1848         cancellation_manager=cancellation_manager)
#    1849
#    1850   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1922       # No tape is watching; skip to running the function.
#    1923       return self._build_call_outputs(self._inference_function.call(
# -> 1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#    1926         args,
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     548               inputs=args,
#     549               attrs=attrs,
# --> 550               ctx=ctx)
#     551         else:
#     552           outputs = execute.execute_with_cancellation(
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
ML_object = MLEngineer(raw_data, num_stocks=40,
                       trading_window = 12, algorithm='SVM', small_sample = False, method='median')
ML_object.data_processing()

# %%
ML_object.clean_data.head()

# %% [markdown]
# ###  2. Return Prediction

# %%
time_list =['2014-10-01', '2018-11-01']
returns_long = ML_object.profit_construct(time_list, strategy ='long_equal_weighted')

# %%
returns_short = - np.array(ML_object.profit_construct(time_list, strategy ='short_equal_weighted'))

# %% [markdown]
# ### 3. Return Plot

# %%
ML_object.return_plot(returns_long)

# %%
ML_object.return_plot(returns_short)
